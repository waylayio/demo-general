# %% [markdown]
# # Waylay Python SDK api self documentation
#
# This notebook illustrates how you can list and discover the currently supported Waylay API in the Python SDK.
#
# The supported API (services, resources, actions) will depend on the version of the SDK you have installed:

# %%
import waylay
from IPython.display import display, Markdown, HTML

waylay.__version__
# Out:
# 'v0.4.0rc03'

# %%
waylay_client = waylay.WaylayClient.from_profile('demo-io')

# %% [markdown]
# The `util.info.action_info_html` tool in the SDK provides a full overview of available services.

# %%
info = waylay_client.util.info
HTML(info.action_info_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#   <tr>
#     <th>service</th>
#     <th>resource</th>
#     <th>action</th>
#     <th>method</th>
#     <th>url</th>
#     <th>description</th>
#   </tr>
# </thead>
# <tbody>
#     <tr>
#       <th rowspan="8" valign="top">analytics</th>
#       <th rowspan="7" valign="top">query</th>
#       <th>list</th>
#       <td>GET</td>
#       <td>/config/query</td>
#       <td><div>List or search <em>Query Configurations</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['queries', 'name']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=data-query-search-api" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/query%20config/get_config_query" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>create</th>
#       <td>POST</td>
#       <td>/config/query</td>
#       <td><div>Create a new <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['query']         : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=create" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/query%20config/post_config_query" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>get</th>
#       <td>GET</td>
#       <td>/config/query/{}</td>
#       <td><div>Fetch the named <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['query']         : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=retrieve" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/query%20config/get_config_query__query_name_" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>remove</th>
#       <td>DELETE</td>
#       <td>/config/query/{}</td>
#       <td><div>Remove the named <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=delete" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/query%20config/delete_config_query__query_name_" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>replace</th>
#       <td>PUT</td>
#       <td>/config/query/{}</td>
#       <td><div>Replace the named <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['query']         : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=replace" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/query%20config/put_config_query__query_name_" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>data</th>
#       <td>GET</td>
#       <td>/data/query/{}</td>
#       <td><div>Execute the timeseries query specified by the named <em>Query Configuration</em>.</div>
# <div><pre>Returns a pandas dataframe. Arguments that configure this behaviour:
#     `render_mode=RENDER_MODE_COMPACT_WS`: render mode requested to the analytics server.
#     `response_constructor='tsa_dataframe'`: converter for the data response.
#     `multi_frame=MultiFrameHandling.JOIN`: Join all dataframes, using table attributes.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=query-execution" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/data/get_data_query__query_name_" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>execute</th>
#       <td>POST</td>
#       <td>/data/query</td>
#       <td><div>Execute the timeseries query specified in the request body.</div>
# <div><pre>Returns a pandas dataframe. Arguments that configure this behaviour:
#     `render_mode=RENDER_MODE_COMPACT_WS`: render mode requested to the analytics server.
#     `response_constructor='tsa_dataframe'`: converter for the data response.
#     `multi_frame=MultiFrameHandling.JOIN`: Join all dataframes, using table attributes.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=query-execution" target="_doc">doc</a> | <a href="https://ts-analytics-io.waylay.io/apidocs/#/data/post_data_query" target="_apidoc">apidoc</a></div></td>
#     </tr>
#     <tr>
#       <th>about</th>
#       <th>version</th>
#       <td>GET</td>
#       <td>/</td>
#       <td><div>Version info of the <em>Analytics Service</em> at this endpoint.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div></td>
#     </tr>
#     <tr>
#       <th rowspan="19" valign="top">byoml</th>
#       <th rowspan="12" valign="top">model</th>
#       <th>list</th>
#       <td>GET</td>
#       <td>/models</td>
#       <td><div>List the metadata of the deployed <em>BYOML Models</em></div>
# <div><pre>Logs server timing on waylay.service.byoml.model.server-timing at level INFO
#
# Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['available_models']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/byoml/?id=overview-of-the-api" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>list_names</th>
#       <td>GET</td>
#       <td>/models</td>
#       <td><div>List the names of deployed <em>BYOML Models</em></div>
# <div><pre>Logs server timing on waylay.service.byoml.model.server-timing at level INFO
#
# Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['available_models', 'name']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/byoml/?id=overview-of-the-api" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>upload</th>
#       <td>POST</td>
#       <td>/models</td>
#       <td><div>Build and create a new <em>BYOML Model</em> as specified in the request</div>
# <div><pre>Upload a new machine learning model with given name, framework and description.
#
#         Parameters:
#             model_name      The name of the model.
#             trained_model   The model object (will be serialised to an zip archive before upload),
#                             or a file path to the serialized model file or folder.
#             framework       One of the supported frameworks (default 'sklear

# %% [markdown]
# This listing can be optionally filtered on service name, resource name and/or included documentation links.

# %%
HTML(info.action_info_html('analytics', links=['doc']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#   <tr>
#     <th>service</th>
#     <th>resource</th>
#     <th>action</th>
#     <th>method</th>
#     <th>url</th>
#     <th>description</th>
#   </tr>
# </thead>
# <tbody>
#     <tr>
#       <th rowspan="8" valign="top">analytics</th>
#       <th rowspan="7" valign="top">query</th>
#       <th>list</th>
#       <td>GET</td>
#       <td>/config/query</td>
#       <td><div>List or search <em>Query Configurations</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['queries', 'name']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=data-query-search-api" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>create</th>
#       <td>POST</td>
#       <td>/config/query</td>
#       <td><div>Create a new <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['query']         : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=create" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>get</th>
#       <td>GET</td>
#       <td>/config/query/{}</td>
#       <td><div>Fetch the named <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['query']         : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=retrieve" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>remove</th>
#       <td>DELETE</td>
#       <td>/config/query/{}</td>
#       <td><div>Remove the named <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=delete" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>replace</th>
#       <td>PUT</td>
#       <td>/config/query/{}</td>
#       <td><div>Replace the named <em>Query Configuration</em>.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['query']         : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=replace" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>data</th>
#       <td>GET</td>
#       <td>/data/query/{}</td>
#       <td><div>Execute the timeseries query specified by the named <em>Query Configuration</em>.</div>
# <div><pre>Returns a pandas dataframe. Arguments that configure this behaviour:
#     `render_mode=RENDER_MODE_COMPACT_WS`: render mode requested to the analytics server.
#     `response_constructor='tsa_dataframe'`: converter for the data response.
#     `multi_frame=MultiFrameHandling.JOIN`: Join all dataframes, using table attributes.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=query-execution" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>execute</th>
#       <td>POST</td>
#       <td>/data/query</td>
#       <td><div>Execute the timeseries query specified in the request body.</div>
# <div><pre>Returns a pandas dataframe. Arguments that configure this behaviour:
#     `render_mode=RENDER_MODE_COMPACT_WS`: render mode requested to the analytics server.
#     `response_constructor='tsa_dataframe'`: converter for the data response.
#     `multi_frame=MultiFrameHandling.JOIN`: Join all dataframes, using table attributes.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/query/?id=query-execution" target="_doc">doc</a></div></td>
#     </tr>
#     <tr>
#       <th>about</th>
#       <th>version</th>
#       <td>GET</td>
#       <td>/</td>
#       <td><div>Version info of the <em>Analytics Service</em> at this endpoint.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div></td>
#     </tr>
#   </tbody>
# </table>

# %%
HTML(info.action_info_html('storage', resource=['folder','object']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#   <tr>
#     <th>service</th>
#     <th>resource</th>
#     <th>action</th>
#     <th>method</th>
#     <th>url</th>
#     <th>description</th>
#   </tr>
# </thead>
# <tbody>
#     <tr>
#       <th rowspan="10" valign="top">storage</th>
#       <th rowspan="6" valign="top">object</th>
#       <th>sign_get</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}?sign=GET</td>
#       <td><div>Create a signed http GET link for the given bucket and object path.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['_links', 'get_object', 'href']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=sign_url" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/list_or_get_objects_bucket__bucket_name___object_path__get" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//subscription/%7Bbucket_name%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>sign_post</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}?sign=POST</td>
#       <td><div>Create a signed http POST link for the given bucket and object path.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['_links', 'post_object']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=sign_url" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/list_or_get_objects_bucket__bucket_name___object_path__get" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//subscription/%7Bbucket_name%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>sign_put</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}?sign=PUT</td>
#       <td><div>Create a signed http PUT link for the given bucket and object path.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['_links', 'put_object', 'href']: extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=sign_url" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/list_or_get_objects_bucket__bucket_name___object_path__get" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//subscription/%7Bbucket_name%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>stat</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}?stat=true</td>
#       <td><div>Get the object metadata for the given bucket and object path.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=get-object" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/list_or_get_objects_bucket__bucket_name___object_path__get" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//subscription/%7Bbucket_name%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>remove</th>
#       <td>DELETE</td>
#       <td>/bucket/{}/{}</td>
#       <td><div>Remove the object at the given bucket and object path.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=delete-object-or-folder" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/delete_object_bucket__bucket_name___object_path__delete" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//subscription/%7Bbucket_name%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>list</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}</td>
#       <td><div>List objects in given bucket with a given path prefix.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['objects']       : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=list-object" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/list_or_get_objects_bucket__bucket_name___object_path__get" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//subscription/%7Bbucket_name%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">folder</th>
#       <th>list</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}/</td>
#       <td><div>List objects in this folder.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=['objects']       : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=list-object" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/list_or_get_objects_bucket__bucket_name___object_path__get" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//bucket/%7Bbucket_name%7D/%7Bobject_path%7D/get" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>create</th>
#       <td>PUT</td>
#       <td>/bucket/{}/{}/</td>
#       <td><div>Create a folder.</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=put-folder" target="_doc">doc</a> | <a href="https://storage-io.waylay.io/docs#/storage/create_folder_bucket__bucket_name___object_path___put" target="_apidoc">apidoc</a> | <a href="https://storage-io.waylay.io/openapi.json#/paths//bucket/%7Bbucket_name%7D/%7Bobject_path%7D//put" target="_openapi">openapi</a></div></td>
#     </tr>
#     <tr>
#       <th>stat</th>
#       <td>GET</td>
#       <td>/bucket/{}/{}/?stat=true</td>
#       <td><div>Get the details of this folder</div>
# <div><pre>Returns the (parsed json) response body. Arguments that configure response handling:
#     select_path=[]                : extract path from the response body.
#     response_constructor          : transforms the extracted response.
#     raw=False                     : If `True`, returns unmodified http response information.</pre></div>
# <div><a href="https://docs.waylay.io/#/api/storage/?id=ge

# %% [markdown]
# ### self description
#
# The SDK provides the following introspection metadata:
#
# The `services` property of the waylay client lists the available services

# %%
list( service.name for service in waylay_client.services )
# Out:
# ['analytics', 'byoml', 'timeseries', 'api', 'storage', 'util', 'etl', 'data']

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

display(Markdown(f'#### services supported in Waylay Python SDK {waylay.__version__}'))
display(pd.DataFrame(
    [(srv.name, srv.description, srv.root_url) for srv in waylay_client.services], 
    columns=['name','description', 'root_url']
))
# Out:
# #### services supported in Waylay Python SDK v0.4.0rc03
#          name                                                description  \
# 0   analytics                     REST client for the Analytics Service.
# 1       byoml                  REST client for the Waylay BYOML Service.
# 2  timeseries  Tool service the timeseries import and export operations.
# 3         api      REST client for the main Waylay Api Service (engine).
# 4     storage                REST client for the Waylay Storage Service.
# 5        util                        Utility Service for the python SDK.
# 6         etl                    REST client for the Waylay ETL Service.
# 7        data          REST client for the Waylay Data Service (broker).
#
#                             root_url
# 0  https://ts-analytics-io.waylay.io
# 1         https://byoml-io.waylay.io
# 2       https://io-testing.waylay.io
# 3       https://io-testing.waylay.io
# 4       https://storage-io.waylay.io
# 5       https://io-testing.waylay.io
# 6    https://etl-export-io.waylay.io
# 7          https://data-io.waylay.io

# %% [markdown]
# The `resources` property of a SDK service list the supported REST resources.|

# %%
display(Markdown(f'#### `storage` resources supported in Waylay Python SDK {waylay.__version__}'))

display(pd.DataFrame(
   [(res.name, res.__doc__) for res in waylay_client.storage.resources ], 
    columns=['name','description']
))
# Out:
# #### `storage` resources supported in Waylay Python SDK v0.4.0rc03
#            name  \
# 0        bucket
# 1        object
# 2        folder
# 3  subscription
# 4         about
#
#                                                               description
# 0         REST Resource for the 'bucket' entity of the 'storage' service.
# 1         REST Resource for the 'object' entity of the 'storage' service.
# 2  REST Resource for the folder 'object' entity of the 'storage' service.
# 3   REST Resource for the 'subscription' entity of the 'storage' service.
# 4                                       Static information about version.

# %% [markdown]
# The `actions` property of a SDK resource list the supported REST actions.

# %%
display(Markdown(f'#### `storage.subscription` actions supported in Waylay Python SDK {waylay.__version__}'))

display(pd.DataFrame(
[ 
    (action.name, action.method, action.url, action.description) 
     for action in waylay_client.storage.subscription.actions.values()
], columns=['name','method','url','description']
))
# Out:
# #### `storage.subscription` actions supported in Waylay Python SDK v0.4.0rc03
#          name  method                  url  \
# 0        list     GET     /subscription/{}
# 1         get     GET  /subscription/{}/{}
# 2      create    POST     /subscription/{}
# 3     replace     PUT  /subscription/{}/{}
# 4      remove  DELETE  /subscription/{}/{}
# 5  remove_all  DELETE     /subscription/{}
#
#                                                         description
# 0                  List available subscriptions for a given bucket.
# 1       Retrieve the representation of a notification subscription.
# 2                           Create a new notification subscription.
# 3  Create or Replace the definition of a notification subscription.
# 4                               Remove a notification subscription.
# 5        Remove all notification subscription that satisfy a query.
